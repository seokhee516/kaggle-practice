# %% [markdown]
# <a href="https://colab.research.google.com/github/seokhee516/kaggle-practice/blob/main/AI_08_%EC%A0%95%EC%84%9D%ED%9D%AC_Section1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 5s (2,103 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import numpy as np
import missingno as msno
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
df = pd.read_csv('df.csv', index_col=0)

# %%
data = df.drop('Year',axis=1).groupby('Genre').mean()

# %%
f,ax=plt.subplots(2,2,figsize=(15,10))

data.iloc[:,0].sort_values(ascending=True).plot(kind="barh",color='#0070dd',width=0.8,xlabel="",ax=ax[0,0])
ax[0,0].set_title('북미지역 장르별 평균 출고량')

data.iloc[:,1].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[0,1])
ax[0,1].set_title('유럽지역 장르별 평균 출고량')

data.iloc[:,2].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[1,0])
ax[1,0].set_title('일본지역 장르별 평균 출고량')

data.iloc[:,3].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[1,1])
ax[1,1].set_title('기타지역 장르별 평균 출고량')
f.tight_layout()

# %%
f,ax=plt.subplots(2,2,figsize=(15,10))

data.iloc[:,0].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[0,0])
ax[0,0].set_title('북미지역 장르별 평균 출고량')

data.iloc[:,1].sort_values(ascending=True).plot(kind="barh",color='#0070dd',width=0.8,xlabel="",ax=ax[0,1])
ax[0,1].set_title('유럽지역 장르별 평균 출고량')

data.iloc[:,2].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[1,0])
ax[1,0].set_title('일본지역 장르별 평균 출고량')

data.iloc[:,3].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[1,1])
ax[1,1].set_title('기타지역 장르별 평균 출고량')
f.tight_layout()

# %%
f,ax=plt.subplots(2,2,figsize=(15,10))

data.iloc[:,0].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[0,0])
ax[0,0].set_title('북미지역 장르별 평균 출고량')

data.iloc[:,1].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[0,1])
ax[0,1].set_title('유럽지역 장르별 평균 출고량')

data.iloc[:,2].sort_values(ascending=True).plot(kind="barh",color='#0070dd',width=0.8,xlabel="",ax=ax[1,0])
ax[1,0].set_title('일본지역 장르별 평균 출고량')

data.iloc[:,3].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[1,1])
ax[1,1].set_title('기타지역 장르별 평균 출고량')
f.tight_layout()

# %%
f,ax=plt.subplots(2,2,figsize=(15,10))

data.iloc[:,0].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[0,0])
ax[0,0].set_title('북미지역 장르별 평균 출고량')

data.iloc[:,1].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[0,1])
ax[0,1].set_title('유럽지역 장르별 평균 출고량')

data.iloc[:,2].sort_values(ascending=True).plot(kind="barh",color='#c2c2c2',width=0.8,xlabel="",ax=ax[1,0])
ax[1,0].set_title('일본지역 장르별 평균 출고량')

data.iloc[:,3].sort_values(ascending=True).plot(kind="barh",color='#0070dd',width=0.8,xlabel="",ax=ax[1,1])
ax[1,1].set_title('기타지역 장르별 평균 출고량')

f.tight_layout()

# %%
in80 = ((df['Year'] >= 1980) & (df['Year'] <=1989))
in90 = ((df['Year'] >= 1990) & (df['Year'] <=1999))
in00 = ((df['Year'] >= 2000) & (df['Year'] <=2009))
in10 = ((df['Year'] >= 2010) & (df['Year'] <=2020))

# %%
platform_years_df = pd.DataFrame({
    '80s':df.loc[in80,'Platform'].value_counts(),
    '90s':df.loc[in90,'Platform'].value_counts(),
    '00s':df.loc[in00,'Platform'].value_counts(),
    '10s':df.loc[in10,'Platform'].value_counts()
})

# %%
platform_years_df.sort_values(by=['80s'], axis=0, ascending=False, inplace=True)
data = platform_years_df.iloc[:,0].dropna()
data.plot(kind='bar',color='#0070dd')
plt.rcParams["figure.figsize"] = (10,8)
plt.xticks(rotation=45)
plt.gca().spines['right'].set_visible(False) 
plt.gca().spines['top'].set_visible(False)
plt.title('Platform 트렌드 1980년-1989년');

# %%
platform_years_df2 = platform_years_df.sort_values(by=['90s'], axis=0, ascending=False)
data = platform_years_df2.iloc[:,1].dropna()
data.plot(kind='bar',color='#0070dd')
plt.rcParams["figure.figsize"] = (10,8)
plt.xticks(rotation=45)
plt.gca().spines['right'].set_visible(False) 
plt.gca().spines['top'].set_visible(False)
plt.title('Platform 트렌드 1990년-1999년');

# %%
platform_years_df2 = platform_years_df.sort_values(by=['00s'], axis=0, ascending=False)
data = platform_years_df2.iloc[:,2].dropna()
data.plot(kind='bar',color='#0070dd')
plt.rcParams["figure.figsize"] = (10,8)
plt.xticks(rotation=45)
plt.gca().spines['right'].set_visible(False) 
plt.gca().spines['top'].set_visible(False)
plt.title('Platform 트렌드 2000년-2009년');

# %%
platform_years_df2 = platform_years_df.sort_values(by=['10s'], axis=0, ascending=False)
data = platform_years_df2.iloc[:,3].dropna()
data.plot(kind='bar',color='#0070dd')
plt.rcParams["figure.figsize"] = (10,8)
plt.xticks(rotation=45)
plt.gca().spines['right'].set_visible(False) 
plt.gca().spines['top'].set_visible(False)
plt.title('Platform 트렌드 2010년-2020년');

# %%
tdf = df.loc[in80,'Platform'].value_counts()
tdf2 = tdf[tdf.values > 2]
tdf2['the others'] = tdf[tdf.values < 2].sum()

# %%
data = tdf2
explode = np.full(len(data), 0.01)
explode[0] = 0.1
color = np.full(len(data), '#c2c2c2')
color[0] = '#0070dd'
color[1] = '#ffea00'
color[2] = '#ff8000'
ax = data.plot.pie(autopct='%1.1f%%',
              explode=explode,
              colors=color)
ax.set_title('Platform 비중 1980년-1989년')
ax.set_ylabel('')
plt.rcParams["figure.figsize"] = (8,10);

# %%
df.loc[in90,'Platform'].value_counts()
# Out:
# PS      913
# N64     244
# SNES    239
# SAT     173
# GB       59
# PC       38
# GEN      27
# NES      23
# DC       21
# NG       12
# SCD       6
# 3DO       3
# TG16      2
# WS        2
# GG        1
# PCFX      1
# Name: Platform, dtype: int64

# %%
tdf = df.loc[in90,'Platform'].value_counts()
tdf2 = tdf[tdf.values > 30]
tdf2['the others'] = tdf[tdf.values < 30].sum()

# %%
data = tdf2
explode = np.full(len(data), 0.01)
explode[0] = 0.1
color = np.full(len(data), '#c2c2c2')
color[0] = '#0070dd'
color[1]] = '#ffea00'
color[2] = '#ff8000'
color[3] = '#654321'
ax = data.plot.pie(autopct='%1.1f%%',
              explode=explode,
              colors=color)
ax.set_title('Platform 비중 1990년-1999년')
ax.set_ylabel('')
plt.rcParams["figure.figsize"] = (8,10);
# Out:
# Text(0, 0.5, '')

# %%
df.loc[in00,'Platform'].value_counts()
# Out:
# PS2     2078
# DS      1614
# Wii      834
# XB       799
# GBA      784
# PSP      694
# X360     551
# GC       541
# PC       440
# PS3      415
# PS       272
# N64       69
# DC        31
# GB        27
# WS         4
# Name: Platform, dtype: int64

# %%
tdf = df.loc[in00,'Platform'].value_counts()
tdf2 = tdf[tdf.values > 70]
tdf2['the others'] = tdf[tdf.values < 70].sum()

# %%
data = tdf2
explode = np.full(len(data), 0.01)
explode[0] = 0.1
color = np.full(len(data), '#c2c2c2')
color[0] = '#0070dd'
color[1] = '#ffea00'
color[[2,3,4]] = '#ff8000'
color[[5,6,7]] = '#654321'
ax = data.plot.pie(autopct='%1.1f%%',
              explode=explode,
              colors=color)
ax.set_title('Platform 비중 2000년-2009년')
plt.rcParams["figure.figsize"] = (8,10);
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df.loc[in10,'Platform'].value_counts()
# Out:
# PS3     884
# X360    680
# DS      512
# PSP     499
# 3DS     498
# PC      455
# Wii     450
# PSV     409
# PS4     335
# XOne    212
# WiiU    143
# PS2      43
# Name: Platform, dtype: int64

# %%
data = df.loc[in10,'Platform'].value_counts()
explode = np.full(len(data), 0.01)
explode[0] = 0.1
color = np.full(len(data), '#c2c2c2')
color[0] = '#0070dd'
color[1] = '#ffea00'
color[[2,3,4]] = '#ff8000'
color[[5,6,7]] = '#654321'
ax = data.plot.pie(autopct='%1.1f%%',
              explode=explode,
              colors=color)
ax.set_title('Platform 비중 2010년-2020년')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df['Total_Sales'] = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum(axis=1)

# %%
top = df[df['Total_Sales']>21390000].sort_values(by='Total_Sales', ascending=False)
top = top.sort_values(by="Total_Sales",ascending=True)

# %%
def merge_list(*args, fill_value = None):
  max_length = max([len(lst) for lst in args])
  merged = []
  for i in range(max_length):
    merged.append([
      args[k][i] if i < len(args[k]) else fill_value for k in range(len(args))
    ])
  return merged

lst = merge_list((list(top.Name)),(top.Year.values.astype(int).astype(str)))
index = []
for i in lst:
    index.append(i[0] + ' (' +i[1] + ')')

# %%
top.iloc[:,-1].values
# Out:
# array([21820000., 22000000., 22720000., 23090000., 23430000., 24750000.,
#        28310000., 28610000., 29010000., 30010000., 30260000., 31380000.,
#        33000000., 35830000., 40240000., 82740000.])

# %%
data = top.iloc[:,-5:-1]
data.index = index

# %%
color = np.full(len(data), '#ff8000')
color[0] = '#0070dd'
color[1] = '#ffea00'
color[3] = '#654321'
color[4] = '#654321'

data.plot(kind = 'barh', 
          stacked=True,
          color=color)

plt.gca().spines['right'].set_visible(False) 
plt.gca().spines['top'].set_visible(False)
plt.rcParams["figure.figsize"] = (14,7) 
#plt.rc('xtick', labelsize=20)
plt.title('출고량 상위 0.1% 게임들');

# %%
data = top['Genre'].value_counts()
explode = np.full(len(data), 0.05)
color = np.full(len(data), '#0070dd')
ax = data.plot.pie(autopct='%1.1f%%',
              explode=explode,
              colors=color)
ax.set_title('출고량 상위 0.1% 게임 Genre 비중')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams.update({'legend.fontsize': 15})
plt.rcParams.update({'xtick.labelsize': 22})
plt.rcParams.update({'ytick.labelsize': 22})
plt.rcParams.update({'axes.labelsize': 22})
plt.rcParams.update({'figure.titlesize': 30})
plt.rcParams.update({'axes.titlesize': 30})

# %%
plt.rcParams.update({'figure.titlesize': 28})

# %%
group_names = top['Publisher'].value_counts().index
group_sizes =top['Publisher'].value_counts().values

subgroup_names =top['Platform'].value_counts().index
subgroup_sizes = top['Platform'].value_counts().values

width_num = 0.4

# %%
color1 = np.full(len(group_sizes), '#0070dd')
color1[1] = '#ffea00'
# Outside Ring
fig, ax = plt.subplots()
ax.axis('equal')

pie_outside, _ = ax.pie(group_sizes, 
                        radius=1.3, 
                        labels=group_names, 
                        labeldistance=0.8,
                        colors=color1)
plt.setp(pie_outside,
         width=width_num,
         edgecolor='white')

color2 = np.full(len(subgroup_sizes), '#7fb7ee')
color2[-1] = '#fff8b2'
# Inside Ring
pie_inside, plt_labels, junk = \
ax.pie(subgroup_sizes,
       radius=(1.3 - width_num),
       labels=subgroup_names, 
       labeldistance=0.75,
       colors=color2, 
       autopct='%1.1f%%')

plt.setp(pie_inside,
         width=width_num,
         edgecolor='white')
plt.title('출고량 상위 0.1% 게임들의 Publisher와 Platform 비중');
#fig.tight_layout()

# %%
sns.color_palette("light:#0070dd", as_cmap=True)

# %%
df['Total_Sales'] = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum(axis=1)

# %%
sns.heatmap(df.drop('Year', axis=1).corr(), annot=True,cmap=sns.color_palette("light:#0070dd", as_cmap=True),linewidths=0.2)
plt.xticks(rotation=45)
plt.rcParams["figure.figsize"] = (8,7);

plt.title('출고량 상관관계 분석');

# %%
y_df=pd.DataFrame([df[in80].shape[0],
                   df[in90].shape[0],
                   df[in00].shape[0],
                   df[in10].shape[0]],
                   index=['1980s','1990s','2000s','2010s'])
      

explode = np.full(len(y_df[0]), 0.05)
color = np.full(len(y_df[0]), '#0070dd')
color[[0,1]] = '#c2c2c2'
ax = y_df[0].plot.pie(autopct='%1.1f%%',
                      explode=explode,
                      colors=color)
ax.set_title('연도별 게임 데이터 비중')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = sns.distplot(df['Total_Sales'])
ax.set_title('전체 지역 출고량 히스토그램')
# Out:
# Text(0.5, 1.0, '전체 지역 출고량 히스토그램')
